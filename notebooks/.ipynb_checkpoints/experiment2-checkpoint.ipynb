# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utilsforecast.plotting import plot_series
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import *

# %%
df = pd.read_csv("../data/AEP_hourly.csv", parse_dates = ['Datetime'])
df.head()
# Out:
#              Datetime   AEP_MW
# 0 2004-12-31 01:00:00  13478.0
# 1 2004-12-31 02:00:00  12865.0
# 2 2004-12-31 03:00:00  12577.0
# 3 2004-12-31 04:00:00  12517.0
# 4 2004-12-31 05:00:00  12670.0

# %%
df['unique_id'] = 'Energy'
plot_series(df=df,id_col='unique_id', time_col='Datetime',target_col='AEP_MW' ,palette='viridis')

# %%
plot_series(df=df,id_col='unique_id', time_col='Datetime',target_col='AEP_MW', max_insample_length=80 ,palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Load data
df = pd.read_csv("AEP_hourly.csv")
df['Datetime'] = pd.to_datetime(df['Datetime'])
df = df.set_index('Datetime')

# Use SERIES only
y = df['AEP_MW']

# Daily seasonality
result = seasonal_decompose(
    y,
    model='multiplicative',   # valid because load > 0
    period=24,
    extrapolate_trend='freq'
)

result.plot()
plt.suptitle("Daily Seasonal Decomposition (AEP Load)")
plt.show()
# Out:
# /tmp/ipykernel_6186/929246671.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data = data.asfreq('H')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 5
#       3 data = df
#       4 data = data.asfreq('H')
# ----> 5 result = seasonal_decompose(
#       6     data['AEP_MW'],
#       7     model='multiplicative',
#       8     period=24,
#       9     extrapolate_trend='freq'
#      10 )
#      12 result.plot()
#      13 plt.suptitle('Seasonal Decomposition of Energy Consumption')
#
# File ~/EnergyPrediction/venv/lib/python3.12/site-packages/statsmodels/tsa/seasonal.py:154, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     151 nobs = len(x)
#     153 if not np.all(np.isfinite(x)):
# --> 154     raise ValueError("This function does not handle missing values")
#     155 if model.startswith("m"):
#     156     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
from statsforecast import StatsForecast
from statsforecast.models import Naive, HistoricAverage, WindowAverage, SeasonalNaive

# %%
horizon = 7

models = [
    Naive(),
    HistoricAverage(),
    WindowAverage(winow_size=7),
    SeasonalNaive(seasonal_length=),
]
