# %% [markdown]
# # ETA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df = pd.read_csv('../data/AEP_hourly.csv', index_col='Datetime', parse_dates=True)
df.head()
# Out:
#                       AEP_MW
# Datetime
# 2004-12-31 01:00:00  13478.0
# 2004-12-31 02:00:00  12865.0
# 2004-12-31 03:00:00  12577.0
# 2004-12-31 04:00:00  12517.0
# 2004-12-31 05:00:00  12670.0

# %%
#Plot the dataset
plt.figure(figsize=(10,5))
plt.plot(df)
plt.xlabel('Datetime')
plt.ylabel('Energy consumption')
plt.show()

# %% [markdown]
# # PreProcessing

# %%
df.index.duplicated().drop()print(df.index.is_unique)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.index.duplicated().drop()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
result = seasonal_decompose(
    df, model='multiplicative', extrapolate_trend='freq', period=24)
result.plot()
plt.suptitle('Seasonal Decomposition of Energy consumption Time Series')
plt.tight_layout()
plt.show()

# %%
df['AEP_MW'] = df['AEP_MW'] - df['AEP_MW'].shift(24)
df = df.dropna()

# %%
plt.figure(figsize=(16, 6))
plt.plot(df)
plt.title('Differenced Time Series')
plt.xlabel('Time')
plt.ylabel('Energy Consumption')
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def check_stationarity(Dataframe, difference=False, graph=False):
    # Check for stationarity
    result = adfuller(Dataframe[Dataframe.columns[-1]].dropna())
    print(f'ADF Statistic : {result[0]}')
    print('p-value: %.10f' % result[1])
    count = 0
    if result[1] > 0.05:
        while result[1]>0.05:
            print('Data is not stationary')
            if difference:
                print('Differencing the dataset')
                Dataframe = Dataframe.diff().dropna()
                result = adfuller(Dataframe[Dataframe.columns[-1]])
                print(f'Diff dataset, ADF Statistic : {result[0]}')
                print('p-value: %.10f' % result[1])
                count += 1
                print(f'd : {count}')
                if graph:
                    plt.figure(figsize=(10,5))
                    plt.plot(Dataframe)
                    plt.title('differenced dataset')
                    plt.xlabel('Datetime')
                    plt.ylabel('Energy consumption')
                    plt.show()
            else:
                break
    else:
        print('Data is stationary')

    return Dataframe

# %%
df = check_stationarity(df, True, False)
# Out:
# ADF Statistic : -47.6638771686473
# p-value: 0.0000000000
# Data is stationary

# %%
# Plot ACF and PACF to visualize the optimal lag
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ACF plot (autocorrelation)
plot_acf(df, ax=axes[0], lags=80)
axes[0].set_title('ACF Plot')

# PACF plot (partial autocorrelation)
plot_pacf(df, ax=axes[1], lags=80, method='ywm')
axes[1].set_title('PACF Plot')

plt.show()

# %% [markdown]
# # Model

# %%
train, valid, test = np.split(df, [int(0.6*len(df)),int(0.8*len(df))])
# Out:
# /home/iprabhsidhu/EnergyPrediction/venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
len(train)
# Out:
# 72749

# %%
params = {
    'non_seasonal': (1,0,0),
    'seasonal':(1,1,0,24),
}
Model = SARIMAX(train,order=params['non_seasonal'],seasonal_order=params['seasonal'])
results = Model.fit(disp=False, method='powell')

print(results.summary())
# Out:
# /home/iprabhsidhu/EnergyPrediction/venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/iprabhsidhu/EnergyPrediction/venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/iprabhsidhu/EnergyPrediction/venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/iprabhsidhu/EnergyPrediction/venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
